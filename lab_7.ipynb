# %% [markdown]
# ## Task 2: Use SageMaker Debugger
#
# In this lab, you use Amazon SageMaker Debugger to analyze, detect, and get alerted on bottlenecks, resource utilization rates, and various training issues during training jobs.

# %% [markdown]
# ### Task 2.1: Setup the environment
#
# Install packages and dependencies.

# %%
# %%capture

#install updates
# !apt-get update && apt-get install -y build-essential

# %% [markdown]
# **Note:** Packages can take as long as 5 minutes to install.

# %%
# %%capture

#install-dependencies

# %pip install pytest-cov
# %pip install pytest-filter-subpackage
# %pip install -U sagemaker
# %pip install -U smdebug
# %pip install -U shap
# %pip install protobuf==3.19.4

# %%
#import libraries and set variable values

import sys
import boto3
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import sagemaker
import sagemaker_datawrangler 
import shap

from mpl_toolkits.axes_grid1 import host_subplot

from sagemaker.debugger import (
    CollectionConfig,
    DebuggerHookConfig,
    FrameworkProfile,
    ProfilerConfig,
    ProfilerRule,
    Rule,
    rule_configs,
    TensorBoardOutputConfig
)

from sagemaker.estimator import Estimator
from sagemaker import get_execution_role
from sagemaker.inputs import TrainingInput
from sagemaker.s3 import S3Uploader
from sagemaker.xgboost.estimator import XGBoost
from smdebug.core import modes
from smdebug.trials import create_trial

base_job_name = "lab-7-smdebugger-job"
bucket = sagemaker.Session().default_bucket()
bucket_path = "s3://{}".format(bucket)
prefix = "lab-7-smdebugger"
region = boto3.Session().region_name
role = sagemaker.get_execution_role()
save_interval = 5
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /root/.config/sagemaker/config.yaml
# [2024-11-06 10:04:50.681 sagemaker-data-scienc-ml-t3-medium-26785b5a6dcec944732a404766e8:18 INFO utils.py:28] RULE_JOB_STOP_SIGNAL_FILENAME: None

# %% [markdown]
# Next, import the dataset.

# %%
#import-dataset
lab_test_data = pd.read_csv('adult_data_processed.csv')
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 20)
lab_test_data.head()
# Out:
#    income  age  workclass  education  education_num  marital_status  \
# 0       0   39          1          2              2               1
# 1       0   50          2          2              2               0
# 2       0   38          0          0              0               2
# 3       0   53          0          3              6               0
# 4       0   28          0          2              2               0
#
#    occupation  relationship  race  sex  capital_gain  capital_loss  \
# 0           2             1     0    0          2174             0
# 1           2             0     0    0             0             0
# 2           0             1     0    0             0             0
# 3           0             0     1    0             0             0
# 4           3             4     1    1             0             0
#
#    hours_per_week
# 0              40
# 1              13
# 2              40
# 3              40
# 4              40

# %% [markdown]
# Split the dataset into training (70 percent), validation (20 percent), and test (10 percent) datasets. The training and validation datasets are used to create the model in this lab. You will not use the test dataset in this lab.

# %%
#split-dataset
train_data, validation_data, test_data = np.split(
    lab_test_data.sample(frac=1, random_state=1729),
    [int(0.7 * len(lab_test_data)), int(0.9 * len(lab_test_data))],
)

train_data.to_csv('train_data.csv', index=False, header=False)
validation_data.to_csv('validation_data.csv', index=False, header=False)

feature_names = list(train_data.columns)[1:]

# %% [markdown]
# Now, upload the dataset to Amazon Simple Storage Service (Amazon S3).

# %%
#upload-dataset
sagemaker_session = sagemaker.Session()

train_path = S3Uploader.upload('train_data.csv', 's3://{}/{}'.format(bucket, prefix))
validation_path = S3Uploader.upload('validation_data.csv', 's3://{}/{}'.format(bucket, prefix))

train_input = TrainingInput(train_path, content_type='text/csv')
validation_input = TrainingInput(validation_path, content_type='text/csv')

data_inputs = {
    'train': train_input,
    'validation': validation_input
}

# %% [markdown]
# ### Task 2.2: Modify the training script to enable SageMaker Debugger
#
# You must modify the training script that you used in the previous lab to save tensors to a specified output S3 bucket, specify which tensors to save, and register debug hooks.
#
# To train the model, you will need to configure the following:
# - **Debugger Hook Parameters** to adjust save intervals of the output tensors in the training phases
# - **Debugger Rule Object** to save output tensors for evaluation
#
# For **Debugger Hook Parameters**, you configure the **metrics**, **feature_importance**, **full_shap**, and **average_shap** built-in tensor collections to be captured during training. These are configured in the **collection_configs** for the **debugger_hook_config**. The **full_shap**, and **average_shap** built-in tensor collections use Shapley Values (SHAP). SHAP explains a machine learning (ML) prediction by assuming that each feature value of a training data instance is a player in a game where the prediction is the payout. It then indicates how to distribute the payout fairly among the features. Refer to [SHAP Baselines for Explainability](https://docs.aws.amazon.com/sagemaker/latest/dg/clarify-feature-attribute-shap-baselines.html) for more information about SHAP.
#
# For **Debugger Rule Object**, you configure the following **rule_configs** in **rules**:
# - [Profiler Report](https://docs.aws.amazon.com/sagemaker/latest/dg/debugger-report.html#debugger-profiling-report): Runs rules for system bottleneck detections and autogenerates a profiling report.
# - [XGBoost Training Report](https://docs.aws.amazon.com/sagemaker/latest/dg/debugger-report-xgboost.html): Runs a comprehensive XGBoost Report.
# - [Overfit](https://docs.aws.amazon.com/sagemaker/latest/dg/debugger-built-in-rules.html#overfit): Detects if your model is being overfit to the training data by comparing the validation and training losses.
# - [Overtraining](https://docs.aws.amazon.com/sagemaker/latest/dg/debugger-built-in-rules.html#overtraining): Detects if a model is being overtrained. After several training iterations on a well-behaved model (both training and validation loss decrease), the model approaches to a minimum of the loss function and does not improve anymore. If the model continues training, validation loss might start increasing because the model starts overfitting.
# - [Loss Not Decreasing](https://docs.aws.amazon.com/sagemaker/latest/dg/debugger-built-in-rules.html#loss-not-decreasing): Detects when the loss is not decreasing in value at an adequate rate. These losses must be scalars.

# %%
#enable-debugger
# Retrieve the container image
container = sagemaker.image_uris.retrieve(
    region=boto3.Session().region_name, 
    framework='xgboost', 
    version='1.5-1'
)
# Set up the estimator
xgb = sagemaker.estimator.Estimator(
    container,
    role, 
    base_job_name=base_job_name,
    instance_count=1, 
    instance_type='ml.m5.4xlarge',
    #Set the hyperparameters
    hyperparameters= {
        "max_depth": "5",
        "eta": "0.2",
        "gamma": "4",
        "min_child_weight": "6",
        "subsample": "0.7",
        "objective": "binary:logistic",
        "num_round": "300",
    },
    sagemaker_session=sagemaker_session,
    max_run=1800,
    #Set the Debugger Hook Config
    debugger_hook_config=DebuggerHookConfig(
        s3_output_path=bucket_path,  # Required
        collection_configs=[  # For each of these, a new processing job will be run later in the lab
            CollectionConfig(name="metrics", parameters={"save_interval": str(save_interval)}),
            CollectionConfig(name="feature_importance", parameters={"save_interval": str(save_interval)},),
            CollectionConfig(name="full_shap", parameters={"save_interval": str(save_interval)}),
            CollectionConfig(name="average_shap", parameters={"save_interval": str(save_interval)}),
        ],
    ),
    #Set the Debugger Profiler Configuration
    profiler_config = ProfilerConfig(
        system_monitor_interval_millis=500,
        framework_profile_params=FrameworkProfile()

    ),
    #Configure the Debugger Rule Object
    rules = [
        ProfilerRule.sagemaker(rule_configs.ProfilerReport()),
        Rule.sagemaker(rule_configs.create_xgboost_report()),  
        Rule.sagemaker(rule_configs.overfit()),
        Rule.sagemaker(rule_configs.overtraining()),
        Rule.sagemaker(rule_configs.loss_not_decreasing(),
            rule_parameters={
                "collection_names": "metrics",
                "num_steps": str(save_interval * 2),
            }
        )
    ]
)

# %% [markdown]
# ### Task 2.3: Run the Debugger-enabled training job
#
# Now, train the XGBoost model using the Debugger-enabled script. Training will take approximately 5–10 minutes to run. You can continue with the next task while the training job is running and monitor the job progress using SageMaker Debugger.

# %%
#train-model
xgb.fit(
    inputs = data_inputs
)
# Out:
# 2024-11-06 10:11:44 Starting - Starting the training job...
# 2024-11-06 10:12:18 Downloading - Downloading input dataCreateXgboostReport: InProgress
# Overfit: InProgress
# Overtraining: InProgress
# LossNotDecreasing: InProgress
# ProfilerReport: InProgress
# ...
# 2024-11-06 10:12:47 Downloading - Downloading the training image...
# 2024-11-06 10:13:12 Training - Training image download completed. Training in progress..../miniconda3/lib/python3.8/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# [2024-11-06 10:13:40.063 ip-10-2-113-73.us-west-2.compute.internal:7 INFO utils.py:28] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2024-11-06 10:13:40.085 ip-10-2-113-73.us-west-2.compute.internal:7 INFO profiler_config_parser.py:111] Using config at /opt/ml/input/config/profilerconfig.json.
# [2024-11-06:10:13:40:INFO] Imported framework sagemaker_xgboost_container.training
# [2024-11-06:10:13:40:INFO] Failed to parse hyperparameter objective value binary:logistic to Json.
# Returning the value itself
# [2024-11-06:10:13:40:INFO] No GPUs detected (normal if no gpus installed)
# [2024-11-06:10:13:40:INFO] Running XGBoost Sagemaker in algorithm mode
# [2024-11-06:10:13:40:INFO] Determined 0 GPU(s) available on the instance.
# [2024-11-06:10:13:40:INFO] Determined delimiter of CSV input is ','
# [2024-11-06:10:13:40:INFO] Determined delimiter of CSV input is ','
# [2024-11-06:10:13:40:INFO] files path: /opt/ml/input/data/train
# [2024-11-06:10:13:40:INFO] Determined delimiter of CSV input is ','
# [2024-11-06:10:13:40:INFO] files path: /opt/ml/input/data/validation
# [2024-11-06:10:13:40:INFO] Determined delimiter of CSV input is ','
# [2024-11-06:10:13:40:INFO] Single node training.
# [2024-11-06:10:13:40:INFO] Train matrix has 18886 rows and 12 columns
# [2024-11-06:10:13:40:INFO] Validation matrix has 5396 rows
# [2024-11-06 10:13:40.468 ip-10-2-113-73.us-west-2.compute.internal:7 INFO json_config.py:92] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2024-11-06 10:13:40.469 ip-10-2-113-73.us-west-2.compute.internal:7 INFO hook.py:206] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2024-11-06 10:13:40.469 ip-10-2-113-73.us-west-2.compute.internal:7 INFO hook.py:259] Saving to /opt/ml/output/tensors
# [2024-11-06 10:13:40.469 ip-10-2-113-73.us-west-2.compute.internal:7 INFO state_store.py:77] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2024-11-06:10:13:40:INFO] Debug hook created from config
# [10:13:40] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [2024-11-06 10:13:40.489 ip-10-2-113-73.us-west-2.compute.internal:7 INFO hook.py:427] Monitoring the collections: average_shap, labels, feature_importance, metrics, full_shap, losses, predictions, hyperparameters
# [2024-11-06 10:13:40.492 ip-10-2-113-73.us-west-2.compute.internal:7 INFO hook.py:491] Hook is writing from the hook with pid: 7
# [0]#011train-logloss:0.59367#011validation-logloss:0.59447
# [1]#011train-logloss:0.52615#011validation-logloss:0.52756
# [2]#011train-logloss:0.47870#011validation-logloss:0.48133
# [3]#011train-logloss:0.44298#011validation-logloss:0.44593
# [4]#011train-logloss:0.41552#011validation-logloss:0.41945
# [5]#011train-logloss:0.39441#011validation-logloss:0.39832
# [6]#011train-logloss:0.37789#011validation-logloss:0.38287
# [7]#011train-logloss:0.36538#011validation-logloss:0.37061
# [8]#011train-logloss:0.35522#011validation-logloss:0.36077
# [9]#011train-logloss:0.34674#011validation-logloss:0.35291
# [10]#011train-logloss:0.34001#011validation-logloss:0.34613
# [11]#011train-logloss:0.33316#011validation-logloss:0.33978
# [12]#011train-logloss:0.32897#011validation-logloss:0.33585
# [13]#011train-logloss:0.32510#011validation-logloss:0.33295
# [14]#011train-logloss:0.32217#011validation-logloss:0.33022
# [15]#011train-logloss:0.31972#011validation-logloss:0.32824
# [16]#011train-logloss:0.31723#011validation-logloss:0.32604
# [17]#011train-logloss:0.31448#011validation-logloss:0.32413
# [18]#011train-logloss:0.31219#011validation-logloss:0.32242
# [19]#011train-logloss:0.31045#011validation-logloss:0.32127
# [20]#011train-logloss:0.30840#011validation-logloss:0.31894
# [21]#011train-logloss:0.30663#011validation-logloss:0.31758
# [22]#011train-logloss:0.30575#011validation-logloss:0.31690
# [23]#011train-logloss:0.30449#011validation-logloss:0.31621
# [24]#011train-logloss:0.30326#011validation-logloss:0.31508
# [25]#011train-logloss:0.30243#011validation-logloss:0.31477
# [26]#011train-logloss:0.30107#011validation-logloss:0.31368
# [27]#011train-logloss:0.30025#011validation-logloss:0.31306
# [28]#011train-logloss:0.29975#011validation-logloss:0.31281
# [29]#011train-logloss:0.29931#011validation-logloss:0.31237
# [30]#011train-logloss:0.29875#011validation-logloss:0.31211
# [31]#011train-logloss:0.29835#011validation-logloss:0.31173
# [32]#011train-logloss:0.29761#011validation-logloss:0.31115
# [33]#011train-logloss:0.29722#011validation-logloss:0.31084
# [34]#011train-logloss:0.29634#011validation-logloss:0.31033
# [35]#011train-logloss:0.29537#011validation-logloss:0.30903
# [36]#011train-logloss:0.29487#011validation-logloss:0.30855
# [37]#011train-logloss:0.29429#011validation-logloss:0.30834
# [38]#011train-logloss:0.29366#011validation-logloss:0.30798
# [39]#011train-logloss:0.29324#011validation-logloss:0.30769
# [40]#011train-logloss:0.29268#011validation-logloss:0.30733
# [41]#011train-logloss:0.29217#011validation-logloss:0.30693
# [42]#011train-logloss:0.29179#011validation-logloss:0.30690
# [43]#011train-logloss:0.29159#011validation-logloss:0.30640
# [44]#011train-logloss:0.29118#011validation-logloss:0.30617
# [45]#011train-logloss:0.29063#011validation-logloss:0.30586
# [46]#011train-logloss:0.29010#011validation-logloss:0.30578
# [47]#011train-logloss:0.29002#011validation-logloss:0.30564
# [48]#011train-logloss:0.28988#011validation-logloss:0.30563
# [49]#011train-logloss:0.28955#011validation-logloss:0.30525
# [50]#011train-logloss:0.28920#011validation-logloss:0.30493
# [51]#011train-logloss:0.28913#011validation-logloss:0.30485
# [52]#011train-logloss:0.28882#011validation-logloss:0.30465
# [53]#011train-logloss:0.28870#011validation-logloss:0.30460
# [54]#011train-logloss:0.28844#011validation-logloss:0.30462
# [55]#011train-logloss:0.28827#011validation-logloss:0.30466
# [56]#011train-logloss:0.28781#011validation-logloss:0.30455
# [57]#011train-logloss:0.28739#011validation-logloss:0.30488
# [58]#011train-logloss:0.28739#011validation-logloss:0.30488
# [59]#011train-logloss:0.28727#011validation-logloss:0.30481
# [60]#011train-logloss:0.28693#011validation-logloss:0.30483
# [61]#011train-logloss:0.28684#011validation-logloss:0.30478
# [62]#011train-logloss:0.28675#011validation-logloss:0.30482
# [63]#011train-logloss:0.28664#011validation-logloss:0.30480
# [64]#011train-logloss:0.28645#011validation-logloss:0.30489
# [65]#011train-logloss:0.28637#011validation-logloss:0.30480
# [66]#011train-logloss:0.28620#011validation-logloss:0.30475
# [67]#011train-logloss:0.28593#011validation-logloss:0.30506
# [68]#011train-logloss:0.28574#011validation-logloss:0.30515
# [69]#011train-logloss:0.28565#011validation-logloss:0.30524
# [70]#011train-logloss:0.28552#011validation-logloss:0.30503
# [71]#011train-logloss:0.28545#011validation-logloss:0.30520
# [72]#011train-logloss:0.28518#011validation-logloss:0.30495
# [73]#011train-logloss:0.28498#011validation-logloss:0.30493
# [74]#011train-logloss:0.28489#011validation-logloss:0.30486
# [75]#011train-logloss:0.28486#011validation-logloss:0.30490
# [76]#011train-logloss:0.28476#011validation-logloss:0.30508
# [77]#011train-logloss:0.28462#011validation-logloss:0.30491
# [78]#011train-logloss:0.28462#011validation-logloss:0.30492
# [79]#011train-logloss:0.28436#011validation-logloss:0.30478
# [80]#011train-logloss:0.28437#011validation-logloss:0.30481
# [81]#011train-logloss:0.28432#011validation-logloss:0.30490
# [82]#011train-logloss:0.28404#011validation-logloss:0.30478
# [83]#011train-logloss:0.28385#011validation-logloss:0.30430
# [84]#011train-logloss:0.28381#011validation-logloss:0.30425
# [85]#011train-logloss:0.28364#011validation-logloss:0.30400
# [86]#011train-logloss:0.28359#011validation-logloss:0.30399
# [87]#011train-logloss:0.28354#011validation-logloss:0.30403
# [88]#011train-logloss:0.28349#011validation-logloss:0.30411
# [89]#011train-logloss:0.28321#011validation-logloss:0.30429
# [90]#011train-logloss:0.28314#011validation-logloss:0.30436
# [91]#011train-logloss:0.28300#011validation-logloss:0.30418
# [92]#011train-logloss:0.28300#011validation-logloss:0.30417
# [93]#011train-logloss:0.28290#011validation-logloss:0.30424
# [94]#011train-logloss:0.28271#011validation-logloss:0.30418
# [95]#011train-logloss:0.28259#011validation-logloss:0.30425
# [96]#011train-logloss:0.28230#011validation-logloss:0.30417
# [97]#011train-logloss:0.28215#011validation-logloss:0.30418
# [98]#011train-logloss:0.28207#011validation-logloss:0.30418
# [99]#011train-logloss:0.28191#011validation-logloss:0.30408
# [100]#011train-logloss:0.28181#011validation-logloss:0.30410
# [101]#011train-logloss:0.28149#011validation-logloss:0.30418
# [102]#011train-logloss:0.28142#011validation-logloss:0.30389
# [103]#011train-logloss:0.28133#011validation-logloss:0.30389
# [104]#011train-logloss:0.28133#011validation-logloss:0.30389
# [105]#011train-logloss:0.28127#011validation-logloss:0.30401
# [106]#011train-logloss:0.28109#011validation-logloss:0.30426
# [107]#011train-logloss:0.28109#011validation-logloss:0.30426
# [108]#011train-logloss:0.28095#011validation-logloss:0.30426
# [109]#011train-logloss:0.28072#011validation-logloss:0.30392
# [110]#011train-logloss:0.28067#011validation-logloss:0.30394
# [111]#011train-logloss:0.28067#011validation-logloss:0.30393
# [112]#011train-logloss:0.28064#011validation-logloss:0.30397
# [113]#011train-logloss:0.28057#011validation-logloss:0.30404
# [114]#011train-logloss:0.28053#011validation-logloss:0.30406
# [115]#011train-logloss:0.28045#011validation-logloss:0.30395
# [116]#011train-logloss:0.28046#011validation-logloss:0.30394
# [117]#011train-logloss:0.28041#011validation-logloss:0.30391
# [118]#011train-logloss:0.28027#011validation-logloss:0.30399
# [119]#011train-logloss:0.28019#011validation-logloss:0.30402
# [120]#011train-logloss:0.27989#011validation-logloss:0.30416
# [121]#011train-logloss:0.27979#011validation-logloss:0.30431
# [122]#011train-logloss:0.27973#011validation-logloss:0.30427
# [123]#011train-logloss:0.27943#011validation-logloss:0.30413
# [124]#011train-logloss:0.27934#011validation-logloss:0.30409
# [125]#011train-logloss:0.27933#011validation-logloss:0.30408
# [126]#011train-logloss:0.27926#011validation-logloss:0.30408
# [127]#011train-logloss:0.27882#011validation-logloss:0.30439
# [128]#011train-logloss:0.27860#011validation-logloss:0.30437
# [129]#011train-logloss:0.27835#011validation-logloss:0.30444
# [130]#011train-logloss:0.27813#011validation-logloss:0.30458
# [131]#011train-logloss:0.27807#011validation-logloss:0.30463
# [132]#011train-logloss:0.27807#011validation-logloss:0.30465
# [133]#011train-logloss:0.27807#011validation-logloss:0.30466
# [134]#011train-logloss:0.27808#011validation-logloss:0.30468
# [135]#011train-logloss:0.27807#011validation-logloss:0.30467
# [136]#011train-logloss:0.27808#011validation-logloss:0.30468
# [137]#011train-logloss:0.27808#011validation-logloss:0.30467
# [138]#011train-logloss:0.27770#011validation-logloss:0.30455
# [139]#011train-logloss:0.27770#011validation-logloss:0.30455
# [140]#011train-logloss:0.27770#011validation-logloss:0.30456
# [141]#011train-logloss:0.27757#011validation-logloss:0.30467
# [142]#011train-logloss:0.27757#011validation-logloss:0.30466
# [143]#011train-logloss:0.27743#011validation-logloss:0.30461
# [144]#011train-logloss:0.27731#011validation-logloss:0.30440
# [145]#011train-logloss:0.27724#011validation-logloss:0.30434
# [146]#011train-logloss:0.27724#011validation-logloss:0.30434
# [147]#011train-logloss:0.27724#011validation-logloss:0.30432
# [148]#011train-logloss:0.27717#011validation-logloss:0.30448
# [149]#011train-logloss:0.27715#011validation-logloss:0.30445
# [150]#011train-logloss:0.27715#011validation-logloss:0.30444
# [151]#011train-logloss:0.27715#011validation-logloss:0.30446
# [152]#011train-logloss:0.27715#011validation-logloss:0.30447
# [153]#011train-logloss:0.27715#011validation-logloss:0.30445
# [154]#011train-logloss:0.27710#011validation-logloss:0.30444
# [155]#011train-logloss:0.27691#011validation-logloss:0.30443
# [156]#011train-logloss:0.27665#011validation-logloss:0.30445
# [157]#011train-logloss:0.27653#011validation-logloss:0.30449
# [158]#011train-logloss:0.27649#011validation-logloss:0.30431
# [159]#011train-logloss:0.27649#011validation-logloss:0.30430
# [160]#011train-logloss:0.27645#011validation-logloss:0.30427
# [161]#011train-logloss:0.27645#011validation-logloss:0.30427
# [162]#011train-logloss:0.27631#011validation-logloss:0.30421
# [163]#011train-logloss:0.27631#011validation-logloss:0.30419
# [164]#011train-logloss:0.27631#011validation-logloss:0.30420
# [165]#011train-logloss:0.27631#011validation-logloss:0.30419
# [166]#011train-logloss:0.27631#011validation-logloss:0.30419
# [167]#011train-logloss:0.27631#011validation-logloss:0.30419
# [168]#011train-logloss:0.27614#011validation-logloss:0.30427
# [169]#011train-logloss:0.27614#011validation-logloss:0.30428
# [170]#011train-logloss:0.27614#011validation-logloss:0.30431
# [171]#011train-logloss:0.27610#011validation-logloss:0.30440
# [172]#011train-logloss:0.27610#011validation-logloss:0.30439
# [173]#011train-logloss:0.27610#011validation-logloss:0.30439
# [174]#011train-logloss:0.27600#011validation-logloss:0.30431
# [175]#011train-logloss:0.27592#011validation-logloss:0.30439
# [176]#011train-logloss:0.27592#011validation-logloss:0.30440
# [177]#011train-logloss:0.27592#011validation-logloss:0.30439
# [178]#011train-logloss:0.27592#011validation-logloss:0.30438
# [179]#011train-logloss:0.27584#011validation-logloss:0.30440
# [180]#011train-logloss:0.27568#011validation-logloss:0.30445
# [181]#011train-logloss:0.27563#011validation-logloss:0.30438
# [182]#011train-logloss:0.27563#011validation-logloss:0.30436
# [183]#011train-logloss:0.27558#011validation-logloss:0.30428
# [184]#011train-logloss:0.27558#011validation-logloss:0.30428
# [185]#011train-logloss:0.27550#011validation-logloss:0.30438
# [186]#011train-logloss:0.27550#011validation-logloss:0.30437
# [187]#011train-logloss:0.27539#011validation-logloss:0.30439
# [188]#011train-logloss:0.27530#011validation-logloss:0.30442
# [189]#011train-logloss:0.27524#011validation-logloss:0.30437
# [190]#011train-logloss:0.27522#011validation-logloss:0.30445
# [191]#011train-logloss:0.27522#011validation-logloss:0.30445
# [192]#011train-logloss:0.27521#011validation-logloss:0.30446
# [193]#011train-logloss:0.27521#011validation-logloss:0.30448
# [194]#011train-logloss:0.27518#011validation-logloss:0.30436
# [195]#011train-logloss:0.27515#011validation-logloss:0.30437
# [196]#011train-logloss:0.27503#011validation-logloss:0.30451
# [197]#011train-logloss:0.27473#011validation-logloss:0.30465
# [198]#011train-logloss:0.27464#011validation-logloss:0.30452
# [199]#011train-logloss:0.27464#011validation-logloss:0.30452
# [200]#011train-logloss:0.27464#011validation-logloss:0.30452
# [201]#011train-logloss:0.27455#011validation-logloss:0.30420
# [202]#011train-logloss:0.27455#011validation-logloss:0.30418
# [203]#011train-logloss:0.27455#011validation-logloss:0.30420
# [204]#011train-logloss:0.27450#011validation-logloss:0.30423
# [205]#011train-logloss:0.27435#011validation-logloss:0.30418
# [206]#011train-logloss:0.27426#011validation-logloss:0.30430
# [207]#011train-logloss:0.27426#011validation-logloss:0.30431
# [208]#011train-logloss:0.27426#011validation-logloss:0.30431
# [209]#011train-logloss:0.27418#011validation-logloss:0.30418
# [210]#011train-logloss:0.27418#011validation-logloss:0.30418
# [211]#011train-logloss:0.27417#011validation-logloss:0.30427
# [212]#011train-logloss:0.27418#011validation-logloss:0.30429
# [213]#011train-logloss:0.27417#011validation-logloss:0.30429
# [214]#011train-logloss:0.27412#011validation-logloss:0.30426
# [215]#011train-logloss:0.27403#011validation-logloss:0.30423
# [216]#011train-logloss:0.27399#011validation-logloss:0.30414
# [217]#011train-logloss:0.27399#011validation-logloss:0.30412
# [218]#011train-logloss:0.27392#011validation-logloss:0.30424
# [219]#011train-logloss:0.27392#011validation-logloss:0.30423
# [220]#011train-logloss:0.27379#011validation-logloss:0.30430
# [221]#011train-logloss:0.27379#011validation-logloss:0.30430
# [222]#011train-logloss:0.27365#011validation-logloss:0.30433
# [223]#011train-logloss:0.27359#011validation-logloss:0.30437
# [224]#011train-logloss:0.27359#011validation-logloss:0.30435
# [225]#011train-logloss:0.27359#011validation-logloss:0.30438
# [226]#011train-logloss:0.27352#011validation-logloss:0.30438
# [227]#011train-logloss:0.27352#011validation-logloss:0.30437
# [228]#011train-logloss:0.27346#011validation-logloss:0.30432
# [229]#011train-logloss:0.27346#011validation-logloss:0.30431
# [230]#011train-logloss:0.27346#011validation-logloss:0.30430
# [231]#011train-logloss:0.27342#011validation-logloss:0.30428
# [232]#011train-logloss:0.27337#011validation-logloss:0.30441
# [233]#011train-logloss:0.27331#011validation-logloss:0.30454
# [234]#011train-logloss:0.27331#011validation-logloss:0.30452
# [235]#011train-logloss:0.27325#011validation-logloss:0.30453
# [236]#011train-logloss:0.27315#011validation-logloss:0.30443
# [237]#011train-logloss:0.27315#011validation-logloss:0.30443
# [238]#011train-logloss:0.27315#011validation-logloss:0.30446
# [239]#011train-logloss:0.27315#011validation-logloss:0.30444
# [240]#011train-logloss:0.27301#011validation-logloss:0.30431
# [241]#011train-logloss:0.27301#011validation-logloss:0.30430
# [242]#011train-logloss:0.27301#011validation-logloss:0.30430
# [243]#011train-logloss:0.27301#011validation-logloss:0.30431
# [244]#011train-logloss:0.27301#011validation-logloss:0.30429
# [245]#011train-logloss:0.27301#011validation-logloss:0.30430
# [246]#011train-logloss:0.27301#011validation-logloss:0.30432
# [247]#011train-logloss:0.27289#011validation-logloss:0.30438
# [248]#011train-logloss:0.27289#011validation-logloss:0.30439
# [249]#011train-logloss:0.27284#011validation-logloss:0.30443
# [250]#011train-logloss:0.27276#011validation-logloss:0.30440
# [251]#011train-logloss:0.27267#011validation-logloss:0.30440
# [252]#011train-logloss:0.27267#011validation-logloss:0.30440
# [253]#011train-logloss:0.27261#011validation-logloss:0.30445
# [254]#011train-logloss:0.27238#011validation-logloss:0.30415
# [255]#011train-logloss:0.27228#011validation-logloss:0.30422
# [256]#011train-logloss:0.27228#011validation-logloss:0.30421
# [257]#011train-logloss:0.27219#011validation-logloss:0.30413
# [258]#011train-logloss:0.27208#011validation-logloss:0.30425
# [259]#011train-logloss:0.27208#011validation-logloss:0.30428
# [260]#011train-logloss:0.27208#011validation-logloss:0.30426
# [261]#011train-logloss:0.27205#011validation-logloss:0.30429
# [262]#011train-logloss:0.27205#011validation-logloss:0.30429
# [263]#011train-logloss:0.27205#011validation-logloss:0.30429
# [264]#011train-logloss:0.27205#011validation-logloss:0.30428
# [265]#011train-logloss:0.27200#011validation-logloss:0.30449
# [266]#011train-logloss:0.27200#011validation-logloss:0.30449
# [267]#011train-logloss:0.27188#011validation-logloss:0.30424
# [268]#011train-logloss:0.27189#011validation-logloss:0.30428
# [269]#011train-logloss:0.27189#011validation-logloss:0.30428
# [270]#011train-logloss:0.27178#011validation-logloss:0.30431
# [271]#011train-logloss:0.27153#011validation-logloss:0.30434
# [272]#011train-logloss:0.27153#011validation-logloss:0.30433
# [273]#011train-logloss:0.27147#011validation-logloss:0.30449
# [274]#011train-logloss:0.27144#011validation-logloss:0.30448
# [275]#011train-logloss:0.27144#011validation-logloss:0.30447
# [276]#011train-logloss:0.27132#011validation-logloss:0.30431
# [277]#011train-logloss:0.27132#011validation-logloss:0.30429
# [278]#011train-logloss:0.27122#011validation-logloss:0.30450
# [279]#011train-logloss:0.27122#011validation-logloss:0.30450
# [280]#011train-logloss:0.27122#011validation-logloss:0.30450
# [281]#011train-logloss:0.27122#011validation-logloss:0.30451
# [282]#011train-logloss:0.27122#011validation-logloss:0.30450
# [283]#011train-logloss:0.27122#011validation-logloss:0.30449
# [284]#011train-logloss:0.27122#011validation-logloss:0.30448
# [285]#011train-logloss:0.27114#011validation-logloss:0.30443
# [286]#011train-logloss:0.27108#011validation-logloss:0.30448
# [287]#011train-logloss:0.27108#011validation-logloss:0.30447
# [288]#011train-logloss:0.27108#011validation-logloss:0.30448
# [289]#011train-logloss:0.27108#011validation-logloss:0.30447
# [290]#011train-logloss:0.27108#011validation-logloss:0.30448
# [291]#011train-logloss:0.27108#011validation-logloss:0.30447
# [292]#011train-logloss:0.27108#011validation-logloss:0.30448
# [293]#011train-logloss:0.27098#011validation-logloss:0.30429
# [294]#011train-logloss:0.27092#011validation-logloss:0.30432
#
# 2024-11-06 10:14:12 Uploading - Uploading generated training model[295]#011train-logloss:0.27092#011validation-logloss:0.30433
# [296]#011train-logloss:0.27092#011validation-logloss:0.30433
# [297]#011train-logloss:0.27092#011validation-logloss:0.30432
# [298]#011train-logloss:0.27092#011validation-logloss:0.30431
# [299]#011train-logloss:0.27093#011validation-logloss:0.30430
#
# 2024-11-06 10:14:47 Completed - Training job completed
# CreateXgboostReport: InProgress
# Overfit: InProgress
# Overtraining: InProgress
# LossNotDecreasing: IssuesFound
# Training seconds: 125
# Billable seconds: 125

# %% [markdown]
# ### Task 2.4: Monitor the training job status
#
# In SageMaker Studio, you can review the trial components, including all the SageMaker Debugger jobs that you started. In this lab, you created an **XGBoost Report** job, an **Overfit** job, an **Overtraining** job, and a **Loss Not Decreasing** job. Explore these in SageMaker Studio.
#
# The next step will bring you to a new tab in SageMaker Studio. To follow these directions, use one of the following options:
# - **Option 1:** View the tabs side by side. To create a split screen view from the main SageMaker Studio window, either drag the **lab_7.ipynb** tab to the side or choose the **lab_7.ipynb** tab, and then from the toolbar, select **File** and **New View for Notebook**. You can now have the directions visible as you explore the feature group.
# - **Option 2:** Switch between the SageMaker Studio tabs to follow these instructions.
#
# 1. Choose the **SageMaker Home** icon.
# 2. Choose **Experiments**.
#
# SageMaker studio opens the **Experiments** tab.
#
# 3. Choose **Unassigned runs**.
# 4. From the list, select the **Name** of the job, which has the Type **SageMakerTrainingJob**.
#
# Details of the Training job are displayed.
#
# 5. On the left side, select the **Debugger** tab.
#
# SageMaker Debugger provides the status of your training job, which you can monitor while the model training is running. When complete, you will see the status of any specified training issues.
#
# The analysis is complete when all the **Status** lines display **No Issues Found** or **Issues Found**. The Debugger rules can take as long as 9 minutes to complete.
#
# If issues are found, it means that there are problems you might want to fix in your model. Are there any issues found for the jobs?
#
# In this lab, you do not resolve any issues found. However, if you want to resolve issues found, you can address them with a combination of processing the dataset and retraining the model with adjusted hyperparameters.
#
# 6. When the analysis is complete, return to the notebook tab labeled **lab_7.ipynb**.

# %% [markdown]
# ### Task 2.5: Perform post-training analysis
#
# With SageMaker Debugger, you can create processing job logs in Amazon CloudWatch that you can use to configure custom alarms. Here, you print the location of where the logs are stored for each metric evaluated.

# %%
#print-urls
def _get_rule_job_name(training_job_name, rule_configuration_name, rule_job_arn):
    """Helper function to get the rule job name with correct casing"""
    return "{}-{}-{}".format(
        training_job_name[:26], rule_configuration_name[:26], rule_job_arn[-8:]
    )


def _get_cw_url_for_rule_job(rule_job_name, region):
    return "https://{}.console.aws.amazon.com/cloudwatch/home?region={}#logStream:group=/aws/sagemaker/ProcessingJobs;prefix={};streamFilter=typeLogStreamPrefix".format(
        region, region, rule_job_name
    )


def get_rule_jobs_cw_urls(xgb):
    region = boto3.Session().region_name
    training_job = xgb.latest_training_job
    training_job_name = training_job.describe()["TrainingJobName"]
    rule_eval_statuses = training_job.describe()["DebugRuleEvaluationStatuses"]

    result = {}
    for status in rule_eval_statuses:
        if status.get("RuleEvaluationJobArn", None) is not None:
            rule_job_name = _get_rule_job_name(
                training_job_name, status["RuleConfigurationName"], status["RuleEvaluationJobArn"]
            )
            result[status["RuleConfigurationName"]] = _get_cw_url_for_rule_job(
                rule_job_name, region
            )
    return result


get_rule_jobs_cw_urls(xgb)
# Out:
# {'CreateXgboostReport': 'https://us-west-2.console.aws.amazon.com/cloudwatch/home?region=us-west-2#logStream:group=/aws/sagemaker/ProcessingJobs;prefix=lab-7-smdebugger-job-2024--CreateXgboostReport-f630f840;streamFilter=typeLogStreamPrefix',
#  'Overfit': 'https://us-west-2.console.aws.amazon.com/cloudwatch/home?region=us-west-2#logStream:group=/aws/sagemaker/ProcessingJobs;prefix=lab-7-smdebugger-job-2024--Overfit-f9983b8d;streamFilter=typeLogStreamPrefix',
#  'Overtraining': 'https://us-west-2.console.aws.amazon.com/cloudwatch/home?region=us-west-2#logStream:group=/aws/sagemaker/ProcessingJobs;prefix=lab-7-smdebugger-job-2024--Overtraining-8e916c5a;streamFilter=typeLogStreamPrefix',
#  'LossNotDecreasing': 'https://us-west-2.console.aws.amazon.com/cloudwatch/home?region=us-west-2#logStream:group=/aws/sagemaker/ProcessingJobs;prefix=lab-7-smdebugger-job-2024--LossNotDecreasing-4dbbae84;streamFilter=typeLogStreamPrefix'}

# %% [markdown]
# Tensors can be retrieved by default collections such as weights, gradients, biases, and losses that SageMaker Debugger creates from your training job in addition to custom collections from tensors. Generate a list of names and values for the saved tensors to determine which tensors to plot for further analysis.

# %%
#retrieve-names
trial = create_trial(xgb.latest_job_debugger_artifacts_path())
trial.tensor_names()
# Out:
# [2024-11-06 10:16:56.593 sagemaker-data-scienc-ml-t3-medium-26785b5a6dcec944732a404766e8:18 INFO s3_trial.py:42] Loading trial debug-output at path s3://sagemaker-us-west-2-440570968020/lab-7-smdebugger-job-2024-11-06-10-11-42-486/debug-output
# [2024-11-06 10:16:59.667 sagemaker-data-scienc-ml-t3-medium-26785b5a6dcec944732a404766e8:18 INFO trial.py:197] Training has ended, will refresh one final time in 1 sec.

# %%
#retrieve-values
trial.tensor("average_shap/f1").values()

# %%
#plot-tensors
shap_values = trial.tensor("full_shap/f10").value(trial.last_complete_step)
shap_no_base = shap_values[:, :-1]
shap_base_value = shap_values[0, -1]
shap.summary_plot(shap_no_base, plot_type="bar", feature_names=feature_names)

# %% [markdown]
# ### Task 2.6: Access the SageMaker Debugger insights dashboard
#
# 1. Return to the **Experiments** tab.
# 2. On the left, select **Debugger**.
# 3. In the **Debugger insights** section, select the available **lab-7-smdebugger-job** from the **Training job name** list.
#
# SageMaker Studio opens a new **Debugger insights tab** for the job and begins loading data.
#
# SageMaker Debugger provides an overview of your model training performance on Amazon Elastic Compute Cloud (Amazon EC2) instances. Explore SageMaker Debugger in SageMaker Studio and examine details contained in the reports.
#
# The **Systems Metrics** tab includes the following sections:
#
# - **Resource utilization summary**
# - **CPU utilization summary**
# - **GPU Utilization summary**
#
# The **Rules** tab includes the following **Insights**:
#
# - **BatchSize**
# - **LowGPUUtiliztion**
# - **CPUBottleneck**
# - **GPUMemoryIncrease**
# - **StepOutlier**
# - **MaxInitializationTime**
# - **IOBottleneck**
# - **LoadBalancing**
#
# Data will populate in the charts and tables if any issues were found.
#
# 4. You can download a Debugger report by choosing the <span style="background-color:#1a1b22; font-size:90%; color:#57c4f8; position:relative; top:-1px; padding-top:3px; padding-bottom:3px; padding-left:10px; padding-right:10px; border-color:#57c4f8; border-width:thin; border-style:solid; border-radius:2px; margin-right:5px; white-space:nowrap">Download report</span> near the top of the **Debugger insights** tab.
#
# ### Conclusion
#
# Congratulations! You have used SageMaker Debugger to analyze, detect, and create alerts for potential issues in model training. You can now use the information generated from your reports and alerts to provide insight into efficiently training and creating a more effective model. The next lab focuses on using SageMaker Clarify to detect bias and provide explainability for model predictions.
#
# ### Cleanup
#
# You have completed this notebook. To move to the next part of the lab, do the following:
#
# - Close this notebook file.
# - Return to the lab session and continue with the **Conclusion**.
